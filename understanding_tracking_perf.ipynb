# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/perdue/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
run track_based_reco_perf.py

# %%
fig = plt.figure(figsize=(18,12))
gs = plt.GridSpec(1, 2)

ax = plt.subplot(gs[0])
im = ax.imshow(arr_all_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Raw event counts (no normalization) ME1B", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[1])
im = ax.imshow(arr_all_minerva1mc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Raw event counts (no normalization) Minerva1", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

#fig.savefig('track_based_all_me1B.pdf')

# %%
fig = plt.figure(figsize=(18,12))
gs = plt.GridSpec(1, 2)

ax = plt.subplot(gs[0])
im = ax.imshow(arr_pass_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Raw event counts, ME1B", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[1])
im = ax.imshow(arr_pass_minerva1mc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Raw event counts, Minerva1", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

# %% [markdown]
# We row normalize (divide by `axis=1` to get the _purity_ - it is saying "okay, I reconstructed an event in target 1, what fraction of the events really come from target 1? what fraction came from other planecodes?, etc."

# %%
fig = plt.figure(figsize=(18,12))
gs = plt.GridSpec(1, 2)

ax = plt.subplot(gs[0])
im = ax.imshow(pur_all_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Row normalized purity - read by row, ME1B", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[1])
im = ax.imshow(pur_all_minerva1mc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Row normalized purity - read by row, Minerva1", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

# %%
fig = plt.figure(figsize=(18,12))
gs = plt.GridSpec(1, 2)

ax = plt.subplot(gs[0])
im = ax.imshow(pur_pass_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Row normalized 'purity', ME1B", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[1])
im = ax.imshow(pur_pass_minerva1mc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Row normalized 'purity', Minerva1", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

# %% [markdown]
# We column normalize (divide by `axis=0` to get the _efficiency_ - it is saying "okay, I have an event really coming from target 1 (reading the "y-axis"), was it reconstructed in target 1?, etc. (reading along the x for a given y)"

# %%
fig = plt.figure(figsize=(18,12))
gs = plt.GridSpec(1, 2)

ax = plt.subplot(gs[0])
im = ax.imshow(eff_all_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Column normalized efficiency - read by column, ME1B", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[1])
im = ax.imshow(eff_all_minerva1mc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Column normalized efficiency - read by column, Minerva1", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

# %%
fig = plt.figure(figsize=(18,12))
gs = plt.GridSpec(1, 2)

ax = plt.subplot(gs[0])
im = ax.imshow(eff_pass_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Column normalized 'efficiency', ME1B", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[1])
im = ax.imshow(eff_pass_minerva1mc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Column normalized 'efficiency', Minerva1", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

# %%
fig = plt.figure(figsize=(26,14))
gs = plt.GridSpec(2, 3)

ax = plt.subplot(gs[0])
im = ax.imshow(arr_all_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Event counts (ME1B)", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[3])
im = ax.imshow(arr_pass_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Event counts, ME1B", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[1])
im = ax.imshow(pur_all_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Row normalized", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[4])
im = ax.imshow(pur_pass_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Row normalized", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[2])
im = ax.imshow(eff_all_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Column normalized efficiency", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

ax = plt.subplot(gs[5])
im = ax.imshow(eff_pass_me1Bmc, cmap=plt.get_cmap('jet'), interpolation='nearest')
cbar = plt.colorbar(im, fraction=0.04)
plt.title("Pass Cuts: Column normalized", fontsize=19)
plt.xlabel('True z-segment', fontsize=19)
plt.ylabel('Reconstructed z-segment', fontsize=19)

fig.savefig('track_based_perf_me1B.pdf')
