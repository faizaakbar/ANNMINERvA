# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline
# Out:
# /Users/perdue/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
f = h5py.File('minosmatch_muondat_me1Amc_test.hdf5', 'r')

# %%
for name in f:
    print name
# Out:
# eventids
# muon_orig_x
# muon_orig_y
# muon_orig_z
# vtx_fit_chi2
# vtx_fit_converged
# vtx_n_tracks_prim
# vtx_reco_t
# vtx_reco_x
# vtx_reco_y
# vtx_reco_z
# vtx_used_short_track

# %%
n, bins, patches = plt.hist(f['muon_orig_x'])

# %%
n, bins, patches = plt.hist(f['muon_orig_y'])

# %%
n, bins, patches = plt.hist(f['muon_orig_z'])

# %%
n, bins, patches = plt.hist(f['vtx_fit_chi2'])

# %%
n, bins, patches = plt.hist(f['vtx_fit_converged'])

# %%
n, bins, patches = plt.hist(f['vtx_n_tracks_prim'])

# %%
n, bins, patches = plt.hist(f['vtx_reco_t'])

# %%
n, bins, patches = plt.hist(f['vtx_reco_x'])

# %%
n, bins, patches = plt.hist(f['vtx_reco_y'])

# %%
n, bins, patches = plt.hist(f['vtx_reco_z'])

# %%
n, bins, patches = plt.hist(f['vtx_used_short_track'])
